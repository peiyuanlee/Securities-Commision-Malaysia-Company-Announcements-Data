# %%
import pandas as pd
import numpy as np

data = pd.read_csv(r"C:\Users\pylee\Documents\Copy of sample_CA_data (for manual categorization).csv")
data
# Out:
#                                                  title date_announced  \
# 0    MULTIPLE PROPOSALS VERTICE BERHAD ("VERTICE" O...      11/9/2020
# 1    OTHERS SHARE GRANT SCHEME OF UP TO 15% OF THE ...      11/9/2020
# 2    OTHERS RHB BANK BERHAD ("RHB BANK")\nDISPOSAL ...      11/9/2020
# 3    MULTIPLE PROPOSALS SINO HUA-AN INTERNATIONAL B...      11/9/2020
# 4    NEW ISSUE OF SECURITIES (CHAPTER 6 OF LISTING ...      11/9/2020
# ..                                                 ...            ...
# 986  OTHERS KHIND HOLDINGS BERHAD ("KHIND" or "THE ...     10/11/2020
# 987  OTHERS LETTER OF INTENT ("LOI") BETWEEN FAST E...     10/11/2020
# 988  OTHERS GD EXPRESS CARRIER BHD ("GDEX" OR "THE ...     10/11/2020
# 989  NEW ISSUE OF SECURITIES (CHAPTER 6 OF LISTING ...     10/11/2020
# 990                 WRIT AND STATEMENT OF CLAIM (WRIT)     10/11/2020
#
#                              company_name    reference_number  \
# 0                          VERTICE BERHAD  GA1-11092020-00062
# 1                     GREEN PACKET BERHAD  GA1-11092020-00036
# 2                         RHB BANK BERHAD  GA1-11092020-00086
# 3        SINO HUA-AN INTERNATIONAL BERHAD  GA1-11092020-00095
# 4                RANHILL UTILITIES BERHAD  GA1-11092020-00054
# ..                                    ...                 ...
# 986                 KHIND HOLDINGS BERHAD  GA1-03112020-00046
# 987              TECHFAST HOLDINGS BERHAD  GA1-10112020-00047
# 988             GD EXPRESS CARRIER BERHAD  GA1-10112020-00069
# 989           KANGER INTERNATIONAL BERHAD  GA1-10112020-00073
# 990  ADVANCE INFORMATION MARKETING BERHAD  GA1-10112020-00048
#
#                                                    url     assigned_category  \
# 0    https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 1    https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 2    https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 3    https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 4    https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# ..                                                 ...                   ...
# 986  https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 987  https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 988  https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 989  https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 990  https://disclosure.bursamalaysia.com/FileAcces...        Reply to Query
#
#                                           sub_category
# 0                                   Multiple Proposals
# 1                                               OTHERS
# 2                                               OTHERS
# 3                                   Multiple Proposals
# 4    New Issue of Securities (Chapter 6 of listing ...
# ..                                                 ...
# 986                                             OTHERS
# 987                                             OTHERS
# 988                                             OTHERS
# 989  New Issue of Securities (Chapter 6 of listing ...
# 990                                                  -
#
# [991 rows x 7 columns]

# %%
set(data["sub_category"])
# Out:
# {'-',
#  'Change in Financial Year End',
#  'Memorandum of Understanding',
#  'Multiple Proposals',
#  'New Issue of Securities (Chapter 6 of listing requirements)',
#  'OTHERS',
#  'Practice Note 17 / Guidance Note 3',
#  'Reply to UMA Query',
#  'Transactions (Chapter 10 of Listing Requirements)',
#  'UMA Query by Bursa'}

# %%
set(cat["keywords"])
# Out:
# {'(Suspension/ Leave) (or from duties)of directors/ principal officer/ CEO',
#  '-',
#  'Award of contracts/ Collaborative Agreement',
#  'Default in payment',
#  'Delay in Issuance of \nDelay in release of first quarter financial report\nDelay in release the (unaudited/ audited) quarterly report\nDelay in release of Annual Report\nDelay in release the audited financial statements',
#  'Deviation of 10% or more between the announced unaudited financial statements and the audited financial statements',
#  'Investigation',
#  'MATERIAL UNCERTAINTY RELATED TO GOING CONCERN\nQUALIFIED OPINION\nADVERSE OPINION\nDISCLAIMER OF OPINION',
#  'Resignation of auditors\nnomination of auditors\nchange of auditors\nchange of external auditors\nappointment of auditors',
#  'Special notice for removal/ appointment of directors/ Requisition by shareholders',
#  'acquisition, disposal',
#  'bonus issue, private placement, fund raising, share issuance, esos'}

# %%
#cleaning category data
cat = pd.read_csv(r"C:\Users\pylee\Documents\table-Copy of sample_CA_data (for manual categorization).csv")
cat = cat[1:]
cat.rename(columns = {'a. A list of announcements that CS wishes to be alerted to':'list', "Unnamed: 2": "subcategory", "Unnamed: 3": "keywords"}, inplace = True)


def prepare_table(col): 
    """
    Removes NaN values and fills in empty spaces
    """
    num = 1
    for i in cat[col]:
        if(pd.isna(i)):
            cat.loc[num][col] = cat.loc[num-1][col]
        num+=1
    
       
prepare_table("list")
prepare_table("Bursa Category")
prepare_table("keywords")

num = 1
for i in cat["list"]:
    cat["list"].loc[num] = i[3:]
    num +=1
    
#clean data
cat["Bursa Category"] = cat["Bursa Category"].replace({"General announcements": "General Announcement", "Unusual Market Activity (UMA)": "Unusual Market Activity",
                                                       "Reply to query": "Reply to Query"})
cat["subcategory"] = cat["subcategory"].replace({"Practice Note 17/ Guidance Note 3": "Practice Note 17 / Guidance Note 3", 
                            "New Issue of Securities (Chapter 6 of Listing Requirements)": "New Issue of Securities (Chapter 6 of listing requirements)",
                            "Others": "OTHERS"})
cat["keywords"] = cat["keywords"].replace({"Delay in Issuance of \nDelay in release of first quarter financial report\nDelay in release the (unaudited/ audited) quarterly report\nDelay in release of Annual Report\nDelay in release the audited financial statements": "Delay",
                                          "(Suspension/ Leave) (or from duties)of directors/ principal officer/ CEO": "Suspension Leave from duties", 
                                         "removal/ appointment of directors/ Requisition by shareholders": "removal appointment Requisition", 
                                         "Resignation of auditors\nnomination of auditors\nchange of auditors\nchange of external auditors\nappointment of auditors": "auditors",
                                         "acquisition, disposal": "acquisition disposal", 
                                           "bonus issue, private placement, fund raising, share issuance, esos": "bonus issue private placement fund raising share issuance esos",
                                          "Deviation of 10% or more between the announced unaudited financial statements and the audited financial statements": "deviation",
                                          "Award of contracts/ Collaborative Agreement" : "Award of contracts Collaborative Agreement",
                                          "Special notice for removal/ appointment of directors/ Requisition by shareholders": "Requisition directors director shareholders removal appointment"})

#cat = cat[cat["subcategory"]!= "Others"]
#cat = cat[cat["keywords"]== "-"]
#data = data[(data["sub_category"]!= "OTHERS") & (data["sub_category"]!= "Multiple Proposals")]

cat
# Out:
#                                                  list  \
# 1   Irregularities/ fraud (conduct investigative r...
# 2            Delay in issuance of financial statement
# 3   Audit opinion - Modified/ Material Uncertainty...
# 4                                   Change of auditor
# 5   Deviation between the profit or loss after tax...
# 6   Transactions (Acquisition, Disposal and etc)\n...
# 7   Transactions (Acquisition, Disposal and etc)\n...
# 8   Transactions (Acquisition, Disposal and etc)\n...
# 9   Transactions (Acquisition, Disposal and etc)\n...
# 10                                          PN17/ GN3
# 11                       Change of financial year end
# 12                                Change of directors
# 13                  Corporate exercise (fund raising)
# 14                  Corporate exercise (fund raising)
# 15        Suspension of directors/ principal officers
# 16                        Change of principal officer
# 17   Requisition notice from shareholders for remo...
# 18                                 Default in payment
# 19                 Clarification of announcement/ UMA
# 20                 Clarification of announcement/ UMA
# 21                 Clarification of announcement/ UMA
#
#                      Bursa Category  \
# 1              General Announcement
# 2              General Announcement
# 3              General Announcement
# 4              General Announcement
# 5              General Announcement
# 6              General Announcement
# 7              General Announcement
# 8              General Announcement
# 9              General Announcement
# 10             General Announcement
# 11                Financial Results
# 12  Change of Corporate Information
# 13             General Announcement
# 14             General Announcement
# 15             General Announcement
# 16  Change of Corporate Information
# 17             General Announcement
# 18             General Announcement
# 19                   Reply to Query
# 20             General Announcement
# 21          Unusual Market Activity
#
#                                           subcategory  \
# 1                                              OTHERS
# 2                                              OTHERS
# 3   Audit Report - Modified Opinion/ Material Unce...
# 4                                              OTHERS
# 5                                              OTHERS
# 6                                  Multiple Proposals
# 7                                              OTHERS
# 8   Transactions (Chapter 10 of Listing Requirements)
# 9                         Memorandum of Understanding
# 10                 Practice Note 17 / Guidance Note 3
# 11                       Change in Financial Year End
# 12                                    Change in Board
# 13                                 Multiple Proposals
# 14  New Issue of Securities (Chapter 6 of listing ...
# 15                                             OTHERS
# 16                        Change in Principal Officer
# 17                                             OTHERS
# 18                                             OTHERS
# 19                                                NaN
# 20                                             OTHERS
# 21                                 Reply to UMA Query
#
#                                              keywords
# 1                                       Investigation
# 2                                               Delay
# 3   MATERIAL UNCERTAINTY RELATED TO GOING CONCERN\...
# 4                                            auditors
# 5                                           deviation
# 6                                acquisition disposal
# 7          Award of contracts Collaborative Agreement
# 8                                                   -
# 9                                                   -
# 10                                                  -
# 11                                                  -
# 12                                                  -
# 13  bonus issue private placement fund raising sha...
# 14                                                  -
# 15                       Suspension Leave from duties
# 16                                                  -
# 17  Requisition directors director shareholders re...
# 18                                 Default in payment
# 19                                                  -
# 20                                                  -
# 21                                                  -

# %%
import nltk
from nltk.corpus import stopwords

stopword = stopwords.words("english")
stopword.extend("-")
label = []
num = 0
while num != len(data):
    labels = cat[cat["Bursa Category"] == data["assigned_category"].loc[num]]
    if(len(labels) == 1):
        label.append(str(labels["list"]))
    else:
        labels = labels[labels["subcategory"] == data["sub_category"].loc[num]]
        if(len(labels) == 1):
            label.append(str(labels["list"]))
        else:
            count = 0
            labLen = len(label)
            for keyword in labels["keywords"]:
                i = keyword.split()
                words = [word for word in i if word not in stopword]
                for word in words:
                    if(word.lower() in data["title"].loc[num].lower()):
                        l = labels.iloc[count]
                        label.append(str(l["list"]))
                        break
                if(labLen != len(label)):
                    break
                count += 1   
            if((count == len(labels)) & (data["sub_category"].loc[num] == "OTHERS")):
                label.append("Clarification of announcement/ UMA")
            elif(count == len(labels)):
                label.append("")
    num+=1
label
# Out:
# ['Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Change of auditor',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Default in payment',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Default in payment',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Default in payment',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Corporate exercise (fund raising)',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Change of auditor',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Change of auditor',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Corporate exercise (fund raising)',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Change of auditor',
#  '11    Change of financial year end\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '11    Change of financial year end\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Default in payment',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Default in payment',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Delay in issuance of financial statement',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  ' Default in payment',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  ' Default in payment',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Irregularities/ fraud (conduct investigative review)',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Suspension of directors/ principal officers',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '11    Change of financial year end\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Default in payment',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Change of auditor',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Delay in issuance of financial statement',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Change of auditor',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Default in payment',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Default in payment',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Change of auditor',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Irregularities/ fraud (conduct investigative review)',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Corporate exercise (fund raising)',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Change of auditor',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Change of auditor',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Change of auditor',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Change of auditor',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Change of auditor',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '11    Change of financial year end\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Default in payment',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  ' Suspension of directors/ principal officers',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
# ...
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '11    Change of financial year end\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Default in payment',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '11    Change of financial year end\nName: list, dtype: object',
#  ' Default in payment',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  ' Corporate exercise (fund raising)',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Default in payment',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Default in payment',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Change of auditor',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Default in payment',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  ' Default in payment',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Change of auditor',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '11    Change of financial year end\nName: list, dtype: object',
#  ' Corporate exercise (fund raising)',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  '',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  'Clarification of announcement/ UMA',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  ' Corporate exercise (fund raising)',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Change of auditor',
#  ' Corporate exercise (fund raising)',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  'Clarification of announcement/ UMA',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object']

# %%
set(label)
# Out:
# {'',
#  ' Corporate exercise (fund raising)',
#  ' Default in payment',
#  ' Requisition notice from shareholders for removal and appointment of directors\xa0',
#  ' Suspension of directors/ principal officers',
#  '10    PN17/ GN3\nName: list, dtype: object',
#  '11    Change of financial year end\nName: list, dtype: object',
#  '14     Corporate exercise (fund raising)\nName: list, dtype: object',
#  '19     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '21     Clarification of announcement/ UMA\nName: list, dtype: object',
#  '8    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  '9    Transactions (Acquisition, Disposal and etc)\\n...\nName: list, dtype: object',
#  'Change of auditor',
#  'Clarification of announcement/ UMA',
#  'Delay in issuance of financial statement',
#  'Irregularities/ fraud (conduct investigative review)',
#  'Transactions (Acquisition, Disposal and etc)\nNote: The etc also includes awards of contracts, signing of MOU, Collaborative agreement'}

# %%
L = pd.DataFrame(label, columns = ["Label"])

# %%
df = pd.concat([data, L], axis = 1)

# %%
df[df["Label"] == ""]
# Out:
#                                                  title date_announced  \
# 513  MULTIPLE PROPOSALS AMANAH HARTA TANAH PNB ("AH...     16/10/2020
# 869  MULTIPLE PROPOSALS PROPOSED ESTABLISHMENT AND ...      4/11/2020
# 942  MULTIPLE PROPOSALS IPMUDA BERHAD ("IPMUDA" OR ...      6/11/2020
#
#                company_name    reference_number  \
# 513  AMANAH HARTA TANAH PNB  GA1-16102020-00029
# 869              IGB BERHAD  GA1-04112020-00024
# 942           IPMUDA BERHAD  GA1-06112020-00065
#
#                                                    url     assigned_category  \
# 513  https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 869  https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
# 942  https://disclosure.bursamalaysia.com/FileAcces...  General Announcement
#
#            sub_category Label
# 513  Multiple Proposals
# 869  Multiple Proposals
# 942  Multiple Proposals

# %%
from pathlib import Path  
filepath = Path('df.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)
